# %%
from nltk import word_tokenize
from nltk.tokenize import sent_tokenize
import re

# import and preprocess the corpus
def preprocess(filename):
    output = ""
    with open(filename, "r", encoding="unicode-escape") as corpus:
        sentence = corpus.read().split('\n')
        for line in sentence:
            output += " " + line
    return output
            
text = preprocess("corpus-2.2.txt")

# remove punctuation
text = re.sub(r'[^\w\s]', '', text)

# make sure all spacing is one white space
text = ' '.join(text.split())
# Out:
# ['Musharrafs',
#  'Last',
#  'Act',
#  'General',
#  'Musharraf',
#  'appeared',
#  'on',
#  'the',
#  'national',
#  'scene',
#  'on',
#  'October',
#  '12',
#  '1999',
#  'when',
#  'he',
#  'ousted',
#  'an',
#  'elected',
#  'government',
#  'and',
#  'announced',
#  'an',
#  'ambitious',
#  'nationbuilding',
#  'project',
#  'Many',
#  'Pakistanis',
#  'disillusioned',
#  'with',
#  'Pakistans',
#  'political',
#  'class',
#  'remained',
#  'mute',
#  'thinking',
#  'that',
#  'he',
#  'might',
#  'deliver',
#  'The',
#  'September',
#  '11',
#  '2001',
#  'terrorist',
#  'attacks',
#  'on',
#  'America',
#  'brought',
#  'Musharraf',
#  'into',
#  'the',
#  'international',
#  'limelight',
#  'as',
#  'he',
#  'agreed',
#  'to',
#  'ditch',
#  'the',
#  'Taliban',
#  'and',
#  'support',
#  'the',
#  'United',
#  'Statesled',
#  'war',
#  'on',
#  'terror',
#  'Musharraf',
#  'clamped',
#  'down',
#  'on',
#  'some',
#  'religious',
#  'militants',
#  'operating',
#  'inside',
#  'Pakistan',
#  'and',
#  'also',
#  'on',
#  'those',
#  'fighting',
#  'Indian',
#  'forces',
#  'in',
#  'Kashmir',
#  'As',
#  'a',
#  'result',
#  'Pakistan',
#  'was',
#  'rewarded',
#  'with',
#  'American',
#  'financial',
#  'assistance',
#  'and',
#  'arms',
#  'In',
#  'furtherance',
#  'of',
#  'his',
#  'realignment',
#  'Musharraf',
#  'sent',
#  'the',
#  'Pakistani',
#  'army',
#  'into',
#  'the',
#  'tribal',
#  'areas',
#  'bordering',
#  'Afghanistan',
#  'for',
#  'the',
#  'first',
#  'time',
#  'since',
#  'Pakistans',
#  'independence',
#  'Operations',
#  'there',
#  'against',
#  'Taliban',
#  'and',
#  'alQaeda',
#  'forces',
#  'brought',
#  'mixed',
#  'results',
#  'Although',
#  'the',
#  'US',
#  'viewed',
#  'Musharraf',
#  'as',
#  'an',
#  'agent',
#  'of',
#  'change',
#  'he',
#  'has',
#  'never',
#  'achieved',
#  'domestic',
#  'political',
#  'legitimacy',
#  'and',
#  'his',
#  'policies',
#  'were',
#  'seen',
#  'as',
#  'rife',
#  'with',
#  'contradictions',
#  'For',
#  'example',
#  'he',
#  'made',
#  'alliances',
#  'with',
#  'Islamist',
#  'political',
#  'forces',
#  'who',
#  'in',
#  '2004',
#  'voted',
#  'for',
#  'constitutional',
#  'changes',
#  'legitimizing',
#  'his',
#  'position',
#  'and',
#  'actions',
#  'At',
#  'the',
#  'same',
#  'time',
#  'he',
#  'sidelined',
#  'moderate',
#  'mainstream',
#  'political',
#  'leaders',
#  'while',
#  'claiming',
#  'that',
#  'he',
#  'stood',
#  'for',
#  'enlightened',
#  'moderation',
#  'A',
#  'series',
#  'of',
#  'illplanned',
#  'military',
#  'operations',
#  'in',
#  'the',
#  'tribal',
#  'areas',
#  'further',
#  'complicated',
#  'the',
#  'situation',
#  'in',
#  'the',
#  'volatile',
#  'border',
#  'region',
#  'Last',
#  'March',
#  'Musharraf',
#  'took',
#  'his',
#  'boldest',
#  'step',
#  'removing',
#  'the',
#  'Chief',
#  'Justice',
#  'of',
#  'the',
#  'Supreme',
#  'Court',
#  'Iftikhar',
#  'Chaudhry',
#  'To',
#  'the',
#  'surprise',
#  'of',
#  'many',
#  'the',
#  'countrys',
#  'legal',
#  'community',
#  'organized',
#  'a',
#  'nationwide',
#  'movement',
#  'to',
#  'restore',
#  'the',
#  'Chief',
#  'Justice',
#  'to',
#  'his',
#  'post',
#  'Hundreds',
#  'of',
#  'thousands',
#  'of',
#  'ordinary',
#  'people',
#  'demanded',
#  'the',
#  'rule',
#  'of',
#  'law',
#  'and',
#  'the',
#  'supremacy',
#  'of',
#  'the',
#  'constitution',
#  'emboldening',
#  'the',
#  'judiciary',
#  'and',
#  'changing',
#  'the',
#  'countrys',
#  'political',
#  'dynamic',
#  'In',
#  'a',
#  'historic',
#  'ruling',
#  'that',
#  'Musharraf',
#  'had',
#  'little',
#  'choice',
#  'but',
#  'to',
#  'accept',
#  'the',
#  'Supreme',
#  'Court',
#  'itself',
#  'reinstated',
#  'the',
#  'Chief',
#  'Justice',
#  'in',
#  'July',
#  'Subsequently',
#  'the',
#  'energized',
#  'judiciary',
#  'continued',
#  'ruling',
#  'against',
#  'government',
#  'decisions',
#  'embarrassing',
#  'the',
#  'government',
#  'especially',
#  'its',
#  'intelligence',
#  'agencies',
#  'Government',
#  'officials',
#  'were',
#  'held',
#  'accountable',
#  'for',
#  'actions',
#  'that',
#  'were',
#  'usually',
#  'beyond',
#  'the',
#  'reach',
#  'of',
#  'the',
#  'law',
#  'ranging',
#  'from',
#  'brutal',
#  'beatings',
#  'of',
#  'journalists',
#  'to',
#  'illegal',
#  'confinement',
#  'for',
#  'national',
#  'security',
#  'Musharraf',
#  'and',
#  'his',
#  'political',
#  'allies',
#  'tried',
#  'to',
#  'adjust',
#  'to',
#  'this',
#  'new',
#  'reality',
#  'but',
#  'their',
#  'patience',
#  'ran',
#  'out',
#  'when',
#  'the',
#  'Supreme',
#  'Court',
#  'took',
#  'up',
#  'petitions',
#  'against',
#  'Musharrafs',
#  'decision',
#  'to',
#  'run',
#  'for',
#  'president',
#  'According',
#  'to',
#  'the',
#  'constitution',
#  'originally',
#  'promulgated',
#  'in',
#  '1973',
#  'by',
#  'an',
#  'elected',
#  'parliament',
#  'a',
#  'serving',
#  'military',
#  'official',
#  'cannot',
#  'run',
#  'for',
#  'an',
#  'elected',
#  'office',
#  'Musharraf',
#  'was',
#  'not',
#  'ready',
#  'to',
#  'give',
#  'up',
#  'his',
#  'military',
#  'post',
#  'but',
#  'also',
#  'wanted',
#  'to',
#  'be',
#  'a',
#  'civilian',
#  'president',
#  'While',
#  'he',
#  'announced',
#  'that',
#  'he',
#  'would',
#  'leave',
#  'his',
#  'military',
#  'position',
#  'if',
#  'he',
#  'was',
#  'elected',
#  'president',
#  'his',
#  'track',
#  'record',
#  'of',
#  'reneging',
#  'on',
#  'his',
#  'promises',
#  'haunted',
#  'the',
#  'judiciary',
#  'The',
#  'proceedings',
#  'of',
#  'the',
#  'court',
#  'over',
#  'the',
#  'last',
#  'few',
#  'weeks',
#  'made',
#  'Musharraf',
#  'jittery',
#  'The',
#  'decision',
#  'of',
#  'the',
#  '11member',
#  'bench',
#  'might',
#  'easily',
#  'have',
#  'gone',
#  'against',
#  'him',
#  'Legally',
#  'cornered',
#  'Musharraf',
#  'has',
#  'now',
#  'decided',
#  'to',
#  'abandon',
#  'constitutionality',
#  'removing',
#  'the',
#  'leading',
#  'judges',
#  'of',
#  'the',
#  'Supreme',
#  'Court',
#  'and',
#  'provincial',
#  'high',
#  'courts',
#  'and',
#  'putting',
#  'curbs',
#  'on',
#  'the',
#  'media',
#  'Lawyers',
#  'human',
#  'rights',
#  'activists',
#  'and',
#  'political',
#  'leaders',
#  'have',
#  'since',
#  'been',
#  'arrested',
#  'There',
#  'is',
#  'widespread',
#  'public',
#  'resentment',
#  'in',
#  'response',
#  'to',
#  'these',
#  'moves',
#  'Rather',
#  'than',
#  'taking',
#  'responsibility',
#  'for',
#  'the',
#  'deteriorating',
#  'security',
#  'situation',
#  'as',
#  'evidenced',
#  'by',
#  'regular',
#  'suicide',
#  'bomb',
#  'attacks',
#  'and',
#  'the',
#  'increasing',
#  'Talibanization',
#  'of',
#  'the',
#  'tribal',
#  'areas',
#  'Musharraf',
#  'has',
#  'tried',
#  'to',
#  'blame',
#  'the',
#  'judiciary',
#  'and',
#  'media',
#  'To',
#  'be',
#  'sure',
#  'in',
#  'some',
#  'cases',
#  'judicial',
#  'activism',
#  'was',
#  'obvious',
#  'though',
#  'within',
#  'the',
#  'realm',
#  'of',
#  'constitutional',
#  'law',
#  'and',
#  'the',
#  'media',
#  'also',
#  'made',
#  'mistakes',
#  'but',
#  'by',
#  'no',
#  'stretch',
#  'of',
#  'the',
#  'imagination',
#  'can',
#  'these',
#  'be',
#  'linked',
#  'to',
#  'religious',
#  'extremism',
#  'or',
#  'support',
#  'for',
#  'militancy',
#  'It',
#  'is',
#  'unlikely',
#  'that',
#  'Musharrafs',
#  'latest',
#  'gambit',
#  'will',
#  'succeed',
#  'as',
#  'his',
#  'popular',
#  'support',
#  'is',
#  'at',
#  'its',
#  'lowest',
#  'ebb',
#  'Pakistans',
#  'armed',
#  'forces',
#  'repeated',
#  'targets',
#  'of',
#  'suicide',
#  'bombers',
#  'have',
#  'become',
#  'demoralized',
#  'It',
#  'is',
#  'difficult',
#  'to',
#  'imagine',
#  'them',
#  'standing',
#  'with',
#  'Musharraf',
#  'should',
#  'civil',
#  'conflict',
#  'erupt',
#  'Nor',
#  'can',
#  'a',
#  'weak',
#  'embattled',
#  'and',
#  'disoriented',
#  'Musharraf',
#  'be',
#  'expected',
#  'to',
#  'fight',
#  'Islamic',
#  'militancy',
#  'effectively',
#  'or',
#  'bring',
#  'political',
#  'stability',
#  'to',
#  'Pakistan',
#  'Opposition',
#  'political',
#  'parties',
#  'are',
#  'drawing',
#  'closer',
#  'together',
#  'and',
#  'former',
#  'Prime',
#  'Minister',
#  'Benazir',
#  'Bhutto',
#  'despite',
#  'progress',
#  'in',
#  'her',
#  'powersharing',
#  'negotiations',
#  'with',
#  'Musharraf',
#  'has',
#  'strongly',
#  'condemned',
#  'his',
#  'actions',
#  'Human',
#  'rights',
#  'bodies',
#  'media',
#  'associations',
#  'and',
#  'lawyers',
#  'organizations',
#  'are',
#  'expected',
#  'to',
#  'defy',
#  'the',
#  'emergency',
#  'which',
#  'will',
#  'pit',
#  'them',
#  'against',
#  'the',
#  'security',
#  'forces',
#  'Terrorists',
#  'may',
#  'also',
#  'benefit',
#  'by',
#  'attacking',
#  'a',
#  'preoccupied',
#  'army',
#  'and',
#  'political',
#  'forces',
#  'aligned',
#  'with',
#  'Musharraf',
#  'In',
#  'the',
#  'event',
#  'of',
#  'sustained',
#  'protests',
#  'and',
#  'potential',
#  'violence',
#  'top',
#  'military',
#  'commanders',
#  'may',
#  'decide',
#  'to',
#  'send',
#  'Musharraf',
#  'home',
#  'a',
#  'decision',
#  'that',
#  'would',
#  'not',
#  'be',
#  'unprecedented',
#  'in',
#  'Pakistans',
#  'chronically',
#  'turbulent',
#  'history',
#  'The',
#  'Making',
#  'of',
#  'a',
#  'Murder',
#  'in',
#  'Pakistan',
#  'Instead',
#  'Bhutto',
#  'had',
#  'to',
#  'pay',
#  'with',
#  'her',
#  'life',
#  'for',
#  'courageously',
#  'challenging',
#  'extremists',
#  'of',
#  'all',
#  'stripes',
#  'from',
#  'AlQaeda',
#  'and',
#  'Taliban',
#  'to',
#  'the',
#  'countrys',
#  'religious',
#  'political',
#  'parties',
#  'and',
#  'military',
#  'hardliners',
#  'As',
#  'heir',
#  'to',
#  'Zulfikar',
#  'Ali',
#  'Bhutto',
#  'the',
#  'legendary',
#  'democratic',
#  'leader',
#  'who',
#  'was',
#  'hanged',
#  'by',
#  'General',
#  'Muhammad',
#  'ZiaulHaqs',
#  'government',
#  'in',
#  '1979',
#  'Benazir',
#  'emerged',
#  'as',
#  'a',
#  'symbol',
#  'of',
#  'resistance',
#  'at',
#  'a',
#  'young',
#  'age',
#  'but',
#  'languished',
#  'in',
#  'jails',
#  'and',
#  'exile',
#  'in',
#  'the',
#  '1980s',
#  'Z',
#  'A',
#  'Bhuttos',
#  'legacy',
#  'was',
#  'empowerment',
#  'of',
#  'the',
#  'impoverished',
#  'and',
#  'defense',
#  'of',
#  'ordinary',
#  'peoples',
#  'rights',
#  'amid',
#  'feudalistic',
#  'politics',
#  'and',
#  'military',
#  'rule',
#  'Rather',
#  'than',
#  'bowing',
#  'to',
#  'the',
#  'military',
#  'junta',
#  'he',
#  'embraced',
#  'the',
#  'gallows',
#  'Hours',
#  'before',
#  'his',
#  'hanging',
#  'Benazir',
#  'was',
#  'allowed',
#  'to',
#  'see',
#  'her',
#  'father',
#  'for',
#  'the',
#  'last',
#  'time',
#  'writing',
#  'in',
#  'her',
#  'autobiography',
#  'I',
#  'told',
#  'him',
#  'on',
#  'my',
#  'oath',
#  'in',
#  'his',
#  'death',
#  'cell',
#  'I',
#  'would',
#  'carry',
#  'on',
#  'his',
#  'work',
#  'She',
#  'largely',
#  'lived',
#  'up',
#  'to',
#  'the',
#  'promise',
#  'Her',
#  'first',
#  'stint',
#  'as',
#  'prime',
#  'minister',
#  '198890',
#  'was',
#  'brief',
#  'and',
#  'disorganized',
#  'Lt',
#  'Gen',
#  'Hamid',
#  'Gul',
#  'the',
#  'former',
#  'InterServices',
#  'Intelligence',
#  'ISI',
#  'chief',
#  'confirmed',
#  'that',
#  'he',
#  'sponsored',
#  'an',
#  'alliance',
#  'of',
#  'rightwing',
#  'political',
#  'parties',
#  'to',
#  'stop',
#  'her',
#  'from',
#  'getting',
#  'a',
#  'parliamentary',
#  'majority',
#  'Information',
#  'about',
#  'Pakistans',
#  'nuclear',
#  'program',
#  'and',
#  'ISI',
#  'operations',
#  'in',
#  'Afghanistan',
#  'were',
#  'out',
#  'of',
#  'her',
#  'domain',
#  'Her',
#  'second',
#  'term',
#  'in',
#  'office',
#  '199396',
#  'was',
#  'longer',
#  'and',
#  'better',
#  'but',
#  'her',
#  'government',
#  'again',
#  'fell',
#  'early',
#  'owing',
#  'to',
#  'charges',
#  'of',
#  'mismanagement',
#  'and',
#  'corruption',
#  'In',
#  'reality',
#  'machinations',
#  'by',
#  'the',
#  'intelligence',
#  'agencies',
#  'also',
#  'played',
#  'a',
#  'part',
#  'The',
#  'military',
#  'had',
#  'developed',
#  'an',
#  'entrenched',
#  'distrust',
#  'of',
#  'her',
#  'given',
#  'her',
#  'position',
#  'as',
#  'a',
#  'popularly',
#  'supported',
#  ...]

# %%
from nltk.util import ngrams


# get ngrams
def get_ngrams(corpus, n):
    ngram = ngrams(corpus.split(), n)
    return [i for i in ngram]
# get ngram frequencies as a dictionary
def ngram_freq(ngram_list):
    freq = {}
    for ngram in ngram_list:
        if ngram in freq:
            freq[ngram] += 1
        else:
            freq[ngram] = 1
    return freq

# get a list of bigrams
bigram_list = get_ngrams(text, 2)

# get a list of trigrams
trigram_list = get_ngrams(text, 3)

bigram_freq = ngram_freq(bigram_list)
trigram_freq = ngram_freq(trigram_list)

# %%
# regular probability
vocabulary = len(trigram_list)
probs={}
for trigram_value, trigram_count in trigram_freq.items():
    probs[trigram_value] = trigram_count / bigram_freq[trigram_value[:-1]]
# Out:
# {('Musharrafs', 'Last', 'Act'): 1.0,
#  ('Last', 'Act', 'General'): 1.0,
#  ('Act', 'General', 'Musharraf'): 1.0,
#  ('General', 'Musharraf', 'appeared'): 0.1111111111111111,
#  ('Musharraf', 'appeared', 'on'): 1.0,
#  ('appeared', 'on', 'the'): 0.4,
#  ('on', 'the', 'national'): 0.0016366612111292963,
#  ('the', 'national', 'scene'): 0.005952380952380952,
#  ('national', 'scene', 'on'): 1.0,
#  ('scene', 'on', 'October'): 1.0,
#  ('on', 'October', '12'): 0.125,
#  ('October', '12', '1999'): 0.5,
#  ('12', '1999', 'when'): 1.0,
#  ('1999', 'when', 'he'): 0.14285714285714285,
#  ('when', 'he', 'ousted'): 0.007575757575757576,
#  ('he', 'ousted', 'an'): 0.5,
#  ('ousted', 'an', 'elected'): 1.0,
#  ('an', 'elected', 'government'): 0.21428571428571427,
#  ('elected', 'government', 'and'): 0.10526315789473684,
#  ('government', 'and', 'announced'): 0.005952380952380952,
#  ('and', 'announced', 'an'): 0.14285714285714285,
#  ('announced', 'an', 'ambitious'): 0.16666666666666666,
#  ('an', 'ambitious', 'nationbuilding'): 0.045454545454545456,
#  ('ambitious', 'nationbuilding', 'project'): 1.0,
#  ('nationbuilding', 'project', 'Many'): 1.0,
#  ('project', 'Many', 'Pakistanis'): 0.5,
#  ('Many', 'Pakistanis', 'disillusioned'): 1.0,
#  ('Pakistanis', 'disillusioned', 'with'): 1.0,
#  ('disillusioned', 'with', 'Pakistans'): 0.25,
#  ('with', 'Pakistans', 'political'): 0.3333333333333333,
#  ('Pakistans', 'political', 'class'): 0.16666666666666666,
#  ('political', 'class', 'remained'): 0.045454545454545456,
#  ('class', 'remained', 'mute'): 1.0,
#  ('remained', 'mute', 'thinking'): 1.0,
#  ('mute', 'thinking', 'that'): 1.0,
#  ('thinking', 'that', 'he'): 0.038461538461538464,
#  ('that', 'he', 'might'): 0.013245033112582781,
#  ('he', 'might', 'deliver'): 0.0625,
#  ('might', 'deliver', 'The'): 1.0,
#  ('deliver', 'The', 'September'): 0.25,
#  ('The', 'September', '11'): 0.5,
#  ('September', '11', '2001'): 0.4883720930232558,
#  ('11', '2001', 'terrorist'): 0.14285714285714285,
#  ('2001', 'terrorist', 'attacks'): 1.0,
#  ('terrorist', 'attacks', 'on'): 0.296875,
#  ('attacks', 'on', 'America'): 0.11764705882352941,
#  ('on', 'America', 'brought'): 0.043478260869565216,
#  ('America', 'brought', 'Musharraf'): 1.0,
#  ('brought', 'Musharraf', 'into'): 1.0,
#  ('Musharraf', 'into', 'the'): 1.0,
#  ('into', 'the', 'international'): 0.014492753623188406,
#  ('the', 'international', 'limelight'): 0.002127659574468085,
#  ('international', 'limelight', 'as'): 1.0,
#  ('limelight', 'as', 'he'): 1.0,
#  ('as', 'he', 'agreed'): 0.027777777777777776,
#  ('he', 'agreed', 'to'): 1.0,
#  ('agreed', 'to', 'ditch'): 0.012658227848101266,
#  ('to', 'ditch', 'the'): 1.0,
#  ('ditch', 'the', 'Taliban'): 1.0,
#  ('the', 'Taliban', 'and'): 0.1568627450980392,
#  ('Taliban', 'and', 'support'): 0.043478260869565216,
#  ('and', 'support', 'the'): 0.058823529411764705,
#  ('support', 'the', 'United'): 0.016260162601626018,
#  ('the', 'United', 'Statesled'): 0.004686035613870665,
#  ('United', 'Statesled', 'war'): 0.42857142857142855,
#  ('Statesled', 'war', 'on'): 0.3333333333333333,
#  ('war', 'on', 'terror'): 0.46710526315789475,
#  ('on', 'terror', 'Musharraf'): 0.0136986301369863,
#  ('terror', 'Musharraf', 'clamped'): 1.0,
#  ('Musharraf', 'clamped', 'down'): 1.0,
#  ('clamped', 'down', 'on'): 0.5,
#  ('down', 'on', 'some'): 0.023255813953488372,
#  ('on', 'some', 'religious'): 0.043478260869565216,
#  ('some', 'religious', 'militants'): 0.2,
#  ('religious', 'militants', 'operating'): 1.0,
#  ('militants', 'operating', 'inside'): 1.0,
#  ('operating', 'inside', 'Pakistan'): 1.0,
#  ('inside', 'Pakistan', 'and'): 0.5,
#  ('Pakistan', 'and', 'also'): 0.017543859649122806,
#  ('and', 'also', 'on'): 0.028985507246376812,
#  ('also', 'on', 'those'): 0.06666666666666667,
#  ('on', 'those', 'fighting'): 0.03571428571428571,
#  ('those', 'fighting', 'Indian'): 1.0,
#  ('fighting', 'Indian', 'forces'): 1.0,
#  ('Indian', 'forces', 'in'): 1.0,
#  ('forces', 'in', 'Kashmir'): 0.029850746268656716,
#  ('in', 'Kashmir', 'As'): 0.05,
#  ('Kashmir', 'As', 'a'): 1.0,
#  ('As', 'a', 'result'): 0.7267326732673267,
#  ('a', 'result', 'Pakistan'): 0.0019047619047619048,
#  ('result', 'Pakistan', 'was'): 1.0,
#  ('Pakistan', 'was', 'rewarded'): 0.2,
#  ('was', 'rewarded', 'with'): 0.3333333333333333,
#  ('rewarded', 'with', 'American'): 0.5,
#  ('with', 'American', 'financial'): 0.047619047619047616,
#  ('American', 'financial', 'assistance'): 0.2,
#  ('financial', 'assistance', 'and'): 0.043478260869565216,
#  ('assistance', 'and', 'arms'): 0.037037037037037035,
#  ('and', 'arms', 'In'): 0.125,
#  ('arms', 'In', 'furtherance'): 1.0,
#  ('In', 'furtherance', 'of'): 1.0,
#  ('furtherance', 'of', 'his'): 0.3333333333333333,
#  ('of', 'his', 'realignment'): 0.002061855670103093,
#  ('his', 'realignment', 'Musharraf'): 1.0,
#  ('realignment', 'Musharraf', 'sent'): 1.0,
#  ('Musharraf', 'sent', 'the'): 1.0,
#  ('sent', 'the', 'Pakistani'): 0.09090909090909091,
#  ('the', 'Pakistani', 'army'): 0.18181818181818182,
#  ('Pakistani', 'army', 'into'): 0.125,
#  ('army', 'into', 'the'): 1.0,
#  ('into', 'the', 'tribal'): 0.00322061191626409,
#  ('the', 'tribal', 'areas'): 0.6666666666666666,
#  ('tribal', 'areas', 'bordering'): 0.07142857142857142,
#  ('areas', 'bordering', 'Afghanistan'): 1.0,
#  ('bordering', 'Afghanistan', 'for'): 1.0,
#  ('Afghanistan', 'for', 'the'): 0.2857142857142857,
#  ('for', 'the', 'first'): 0.03559870550161812,
#  ('the', 'first', 'time'): 0.19133574007220217,
#  ('first', 'time', 'since'): 0.18292682926829268,
#  ('time', 'since', 'Pakistans'): 0.023255813953488372,
#  ('since', 'Pakistans', 'independence'): 0.5,
#  ('Pakistans', 'independence', 'Operations'): 1.0,
#  ('independence', 'Operations', 'there'): 1.0,
#  ('Operations', 'there', 'against'): 1.0,
#  ('there', 'against', 'Taliban'): 0.5,
#  ('against', 'Taliban', 'and'): 1.0,
#  ('Taliban', 'and', 'alQaeda'): 0.17391304347826086,
#  ('and', 'alQaeda', 'forces'): 0.125,
#  ('alQaeda', 'forces', 'brought'): 1.0,
#  ('forces', 'brought', 'mixed'): 1.0,
#  ('brought', 'mixed', 'results'): 1.0,
#  ('mixed', 'results', 'Although'): 0.3333333333333333,
#  ('results', 'Although', 'the'): 1.0,
#  ('Although', 'the', 'US'): 0.044642857142857144,
#  ('the', 'US', 'viewed'): 0.00029717682020802375,
#  ('US', 'viewed', 'Musharraf'): 1.0,
#  ('viewed', 'Musharraf', 'as'): 1.0,
#  ('Musharraf', 'as', 'an'): 0.5,
#  ('as', 'an', 'agent'): 0.007751937984496124,
#  ('an', 'agent', 'of'): 0.5714285714285714,
#  ('agent', 'of', 'change'): 0.2857142857142857,
#  ('of', 'change', 'he'): 0.02564102564102564,
#  ('change', 'he', 'has'): 0.3333333333333333,
#  ('he', 'has', 'never'): 0.02040816326530612,
#  ('has', 'never', 'achieved'): 0.010416666666666666,
#  ('never', 'achieved', 'domestic'): 0.5,
#  ('achieved', 'domestic', 'political'): 1.0,
#  ('domestic', 'political', 'legitimacy'): 0.04,
#  ('political', 'legitimacy', 'and'): 0.16666666666666666,
#  ('legitimacy', 'and', 'his'): 0.02702702702702703,
#  ('and', 'his', 'policies'): 0.005128205128205128,
#  ('his', 'policies', 'were'): 0.09523809523809523,
#  ('policies', 'were', 'seen'): 0.07692307692307693,
#  ('were', 'seen', 'as'): 0.4666666666666667,
#  ('seen', 'as', 'rife'): 0.005154639175257732,
#  ('as', 'rife', 'with'): 1.0,
#  ('rife', 'with', 'contradictions'): 0.16666666666666666,
#  ('with', 'contradictions', 'For'): 1.0,
#  ('contradictions', 'For', 'example'): 1.0,
#  ('For', 'example', 'he'): 0.012658227848101266,
#  ('example', 'he', 'made'): 0.2,
#  ('he', 'made', 'alliances'): 0.0625,
#  ('made', 'alliances', 'with'): 1.0,
#  ('alliances', 'with', 'Islamist'): 0.08333333333333333,
#  ('with', 'Islamist', 'political'): 1.0,
#  ('Islamist', 'political', 'forces'): 0.3333333333333333,
#  ('political', 'forces', 'who'): 0.045454545454545456,
#  ('forces', 'who', 'in'): 0.25,
#  ('who', 'in', '2004'): 0.07692307692307693,
#  ('in', '2004', 'voted'): 0.009345794392523364,
#  ('2004', 'voted', 'for'): 1.0,
#  ('voted', 'for', 'constitutional'): 0.034482758620689655,
#  ('for', 'constitutional', 'changes'): 0.16666666666666666,
#  ('constitutional', 'changes', 'legitimizing'): 0.1,
#  ('changes', 'legitimizing', 'his'): 1.0,
#  ('legitimizing', 'his', 'position'): 1.0,
#  ('his', 'position', 'and'): 0.05555555555555555,
#  ('position', 'and', 'actions'): 0.037037037037037035,
#  ('and', 'actions', 'At'): 0.07142857142857142,
#  ('actions', 'At', 'the'): 1.0,
#  ('At', 'the', 'same'): 0.4988558352402746,
#  ('the', 'same', 'time'): 0.25496688741721857,
#  ('same', 'time', 'he'): 0.016181229773462782,
#  ('time', 'he', 'sidelined'): 0.05555555555555555,
#  ('he', 'sidelined', 'moderate'): 1.0,
#  ('sidelined', 'moderate', 'mainstream'): 1.0,
#  ('moderate', 'mainstream', 'political'): 1.0,
#  ('mainstream', 'political', 'leaders'): 0.2,
#  ('political', 'leaders', 'while'): 0.009259259259259259,
#  ('leaders', 'while', 'claiming'): 1.0,
#  ('while', 'claiming', 'that'): 1.0,
#  ('claiming', 'that', 'he'): 0.08823529411764706,
#  ('that', 'he', 'stood'): 0.002207505518763797,
#  ('he', 'stood', 'for'): 0.3333333333333333,
#  ('stood', 'for', 'enlightened'): 0.125,
#  ('for', 'enlightened', 'moderation'): 0.3333333333333333,
#  ('enlightened', 'moderation', 'A'): 1.0,
#  ('moderation', 'A', 'series'): 1.0,
#  ('A', 'series', 'of'): 1.0,
#  ('series', 'of', 'illplanned'): 0.00909090909090909,
#  ('of', 'illplanned', 'military'): 1.0,
#  ('illplanned', 'military', 'operations'): 1.0,
#  ('military', 'operations', 'in'): 0.2608695652173913,
#  ('operations', 'in', 'the'): 0.2,
#  ('in', 'the', 'tribal'): 0.0004655493482309125,
#  ('tribal', 'areas', 'further'): 0.07142857142857142,
#  ('areas', 'further', 'complicated'): 0.5,
#  ('further', 'complicated', 'the'): 1.0,
#  ('complicated', 'the', 'situation'): 0.5,
#  ('the', 'situation', 'in'): 0.1554054054054054,
#  ('situation', 'in', 'the'): 0.2537313432835821,
#  ('in', 'the', 'volatile'): 0.0004655493482309125,
#  ('the', 'volatile', 'border'): 0.2857142857142857,
#  ('volatile', 'border', 'region'): 0.5,
#  ('border', 'region', 'Last'): 0.3333333333333333,
#  ('region', 'Last', 'March'): 1.0,
#  ('Last', 'March', 'Musharraf'): 1.0,
#  ('March', 'Musharraf', 'took'): 1.0,
#  ('Musharraf', 'took', 'his'): 0.5,
#  ('took', 'his', 'boldest'): 0.3333333333333333,
#  ('his', 'boldest', 'step'): 1.0,
#  ('boldest', 'step', 'removing'): 1.0,
#  ('step', 'removing', 'the'): 1.0,
#  ('removing', 'the', 'Chief'): 0.09090909090909091,
#  ('the', 'Chief', 'Justice'): 0.42857142857142855,
#  ('Chief', 'Justice', 'of'): 0.2222222222222222,
#  ('Justice', 'of', 'the'): 1.0,
#  ('of', 'the', 'Supreme'): 0.0006208609271523179,
#  ('the', 'Supreme', 'Court'): 0.5208333333333334,
#  ('Supreme', 'Court', 'Iftikhar'): 0.01818181818181818,
#  ('Court', 'Iftikhar', 'Chaudhry'): 1.0,
#  ('Iftikhar', 'Chaudhry', 'To'): 1.0,
#  ('Chaudhry', 'To', 'the'): 1.0,
#  ('To', 'the', 'surprise'): 0.08571428571428572,
#  ('the', 'surprise', 'of'): 0.6666666666666666,
#  ('surprise', 'of', 'many'): 0.5714285714285714,
#  ('of', 'many', 'the'): 0.007352941176470588,
#  ('many', 'the', 'countrys'): 0.16666666666666666,
#  ('the', 'countrys', 'legal'): 0.002,
#  ('countrys', 'legal', 'community'): 0.5,
#  ('legal', 'community', 'organized'): 0.25,
#  ('community', 'organized', 'a'): 1.0,
#  ('organized', 'a', 'nationwide'): 0.2,
#  ('a', 'nationwide', 'movement'): 0.14285714285714285,
#  ('nationwide', 'movement', 'to'): 1.0,
#  ('movement', 'to', 'restore'): 0.09090909090909091,
#  ('to', 'restore', 'the'): 0.17857142857142858,
#  ('restore', 'the', 'Chief'): 0.045454545454545456,
#  ('Chief', 'Justice', 'to'): 0.1111111111111111,
#  ('Justice', 'to', 'his'): 0.3333333333333333,
#  ('to', 'his', 'post'): 0.00625,
#  ('his', 'post', 'Hundreds'): 0.2,
#  ('post', 'Hundreds', 'of'): 1.0,
#  ('Hundreds', 'of', 'thousands'): 0.2631578947368421,
#  ('of', 'thousands', 'of'): 0.8877551020408163,
#  ('thousands', 'of', 'ordinary'): 0.005208333333333333,
#  ('of', 'ordinary', 'people'): 0.35294117647058826,
#  ('ordinary', 'people', 'demanded'): 0.02127659574468085,
#  ('people', 'demanded', 'the'): 1.0,
#  ('demanded', 'the', 'rule'): 0.3333333333333333,
#  ('the', 'rule', 'of'): 0.902834008097166,
#  ('rule', 'of', 'law'): 0.8754716981132076,
#  ('of', 'law', 'and'): 0.15770609318996415,
#  ('law', 'and', 'the'): 0.112,
#  ('and', 'the', 'supremacy'): 0.0002051702913418137,
#  ('the', 'supremacy', 'of'): 1.0,
#  ('supremacy', 'of', 'the'): 0.4,
#  ('of', 'the', 'constitution'): 0.0010347682119205299,
#  ('the', 'constitution', 'emboldening'): 0.015384615384615385,
#  ('constitution', 'emboldening', 'the'): 1.0,
#  ('emboldening', 'the', 'judiciary'): 1.0,
#  ('the', 'judiciary', 'and'): 0.21212121212121213,
#  ('judiciary', 'and', 'changing'): 0.058823529411764705,
#  ('and', 'changing', 'the'): 0.4,
#  ('changing', 'the', 'countrys'): 0.04,
#  ('the', 'countrys', 'political'): 0.022,
#  ('countrys', 'political', 'dynamic'): 0.06666666666666667,
#  ('political', 'dynamic', 'In'): 0.3333333333333333,
#  ('dynamic', 'In', 'a'): 1.0,
#  ('In', 'a', 'historic'): 0.004784688995215311,
#  ('a', 'historic', 'ruling'): 0.037037037037037035,
#  ('historic', 'ruling', 'that'): 1.0,
#  ('ruling', 'that', 'Musharraf'): 0.3333333333333333,
#  ('that', 'Musharraf', 'had'): 0.3333333333333333,
#  ('Musharraf', 'had', 'little'): 0.25,
#  ('had', 'little', 'choice'): 0.14285714285714285,
#  ('little', 'choice', 'but'): 0.75,
#  ('choice', 'but', 'to'): 0.7916666666666666,
#  ('but', 'to', 'accept'): 0.016,
#  ('to', 'accept', 'the'): 0.18902439024390244,
#  ('accept', 'the', 'Supreme'): 0.012195121951219513,
#  ('Supreme', 'Court', 'itself'): 0.01818181818181818,
#  ('Court', 'itself', 'reinstated'): 1.0,
#  ('itself', 'reinstated', 'the'): 1.0,
#  ('reinstated', 'the', 'Chief'): 0.5,
#  ('Chief', 'Justice', 'in'): 0.1111111111111111,
#  ('Justice', 'in', 'July'): 0.14285714285714285,
#  ('in', 'July', 'Subsequently'): 0.02702702702702703,
#  ('July', 'Subsequently', 'the'): 1.0,
#  ('Subsequently', 'the', 'energized'): 0.5,
#  ('the', 'energized', 'judiciary'): 1.0,
#  ('energized', 'judiciary', 'continued'): 1.0,
#  ('judiciary', 'continued', 'ruling'): 1.0,
#  ('continued', 'ruling', 'against'): 1.0,
#  ('ruling', 'against', 'government'): 1.0,
#  ('against', 'government', 'decisions'): 0.3333333333333333,
#  ('government', 'decisions', 'embarrassing'): 0.5,
#  ('decisions', 'embarrassing', 'the'): 1.0,
#  ('embarrassing', 'the', 'government'): 0.5,
#  ('the', 'government', 'especially'): 0.0015625,
#  ('government', 'especially', 'its'): 0.5,
#  ('especially', 'its', 'intelligence'): 0.125,
#  ('its', 'intelligence', 'agencies'): 0.5,
#  ('intelligence', 'agencies', 'Government'): 0.1,
#  ('agencies', 'Government', 'officials'): 1.0,
#  ('Government', 'officials', 'were'): 0.5,
#  ('officials', 'were', 'held'): 0.2,
#  ('were', 'held', 'accountable'): 0.08333333333333333,
#  ('held', 'accountable', 'for'): 0.5263157894736842,
#  ('accountable', 'for', 'actions'): 0.058823529411764705,
#  ('for', 'actions', 'that'): 0.25,
#  ('actions', 'that', 'were'): 0.047619047619047616,
#  ('that', 'were', 'usually'): 0.006756756756756757,
#  ('were', 'usually', 'beyond'): 0.14285714285714285,
#  ('usually', 'beyond', 'the'): 1.0,
#  ('beyond', 'the', 'reach'): 0.05555555555555555,
#  ('the', 'reach', 'of'): 1.0,
#  ('reach', 'of', 'the'): 0.0625,
#  ('of', 'the', 'law'): 0.0017246136865342163,
#  ('the', 'law', 'ranging'): 0.007751937984496124,
#  ('law', 'ranging', 'from'): 1.0,
#  ('ranging', 'from', 'brutal'): 0.02040816326530612,
#  ('from', 'brutal', 'beatings'): 0.5,
#  ('brutal', 'beatings', 'of'): 1.0,
#  ('beatings', 'of', 'journalists'): 1.0,
#  ('of', 'journalists', 'to'): 0.2857142857142857,
#  ('journalists', 'to', 'illegal'): 0.2,
#  ('to', 'illegal', 'confinement'): 0.5,
#  ('illegal', 'confinement', 'for'): 1.0,
#  ('confinement', 'for', 'national'): 1.0,
#  ('for', 'national', 'security'): 0.15,
#  ('national', 'security', 'Musharraf'): 0.017543859649122806,
#  ('security', 'Musharraf', 'and'): 1.0,
#  ('Musharraf', 'and', 'his'): 0.36363636363636365,
#  ('and', 'his', 'political'): 0.010256410256410256,
#  ('his', 'political', 'allies'): 0.08333333333333333,
#  ('political', 'allies', 'tried'): 0.16666666666666666,
#  ('allies', 'tried', 'to'): 0.5,
#  ('tried', 'to', 'adjust'): 0.006622516556291391,
#  ('to', 'adjust', 'to'): 0.5555555555555556,
#  ('adjust', 'to', 'this'): 0.045454545454545456,
#  ('to', 'this', 'new'): 0.007905138339920948,
#  ('this', 'new', 'reality'): 0.03225806451612903,
#  ('new', 'reality', 'but'): 0.125,
#  ('reality', 'but', 'their'): 0.16666666666666666,
#  ('but', 'their', 'patience'): 0.029411764705882353,
#  ('their', 'patience', 'ran'): 1.0,
#  ('patience', 'ran', 'out'): 1.0,
#  ('ran', 'out', 'when'): 0.3333333333333333,
#  ('out', 'when', 'the'): 0.6666666666666666,
#  ('when', 'the', 'Supreme'): 0.003766478342749529,
#  ('Supreme', 'Court', 'took'): 0.03636363636363636,
#  ('Court', 'took', 'up'): 0.5,
#  ('took', 'up', 'petitions'): 0.07142857142857142,
#  ('up', 'petitions', 'against'): 1.0,
#  ('petitions', 'against', 'Musharrafs'): 1.0,
#  ('against', 'Musharrafs', 'decision'): 1.0,
#  ('Musharrafs', 'decision', 'to'): 1.0,
#  ('decision', 'to', 'run'): 0.017241379310344827,
#  ('to', 'run', 'for'): 0.0875,
#  ('run', 'for', 'president'): 0.2222222222222222,
#  ('for', 'president', 'According'): 0.08333333333333333,
#  ('president', 'According', 'to'): 1.0,
#  ('According', 'to', 'the'): 0.36153846153846153,
#  ('to', 'the', 'constitution'): 0.0009043226623259179,
#  ('the', 'constitution', 'originally'): 0.015384615384615385,
#  ('constitution', 'originally', 'promulgated'): 1.0,
#  ('originally', 'promulgated', 'in'): 1.0,
#  ('promulgated', 'in', '1973'): 1.0,
#  ('in', '1973', 'by'): 0.058823529411764705,
#  ('1973', 'by', 'an'): 1.0,
#  ('by', 'an', 'elected'): 0.0064516129032258064,
#  ('an', 'elected', 'parliament'): 0.07142857142857142,
#  ('elected', 'parliament', 'a'): 0.25,
#  ('parliament', 'a', 'serving'): 1.0,
#  ('a', 'serving', 'military'): 1.0,
#  ('serving', 'military', 'official'): 1.0,
#  ('military', 'official', 'cannot'): 0.5,
#  ('official', 'cannot', 'run'): 1.0,
#  ('cannot', 'run', 'for'): 0.2,
#  ('run', 'for', 'an'): 0.05555555555555555,
#  ('for', 'an', 'elected'): 0.005291005291005291,
#  ('an', 'elected', 'office'): 0.07142857142857142,
#  ('elected', 'office', 'Musharraf'): 1.0,
#  ('office', 'Musharraf', 'was'): 1.0,
#  ('Musharraf', 'was', 'not'): 0.2,
#  ('was', 'not', 'ready'): 0.008174386920980926,
#  ('not', 'ready', 'to'): 0.5,
#  ('ready', 'to', 'give'): 0.022388059701492536,
#  ('to', 'give', 'up'): 0.2085889570552147,
#  ('give', 'up', 'his'): 0.047619047619047616,
#  ('up', 'his', 'military'): 0.15384615384615385,
#  ('his', 'military', 'post'): 0.2,
#  ('military', 'post', 'but'): 0.5,
#  ('post', 'but', 'also'): 1.0,
#  ('but', 'also', 'wanted'): 0.00196078431372549,
#  ('also', 'wanted', 'to'): 1.0,
#  ('wanted', 'to', 'be'): 0.0625,
#  ('to', 'be', 'a'): 0.059849624060150375,
#  ('be', 'a', 'civilian'): 0.0012578616352201257,
#  ('a', 'civilian', 'president'): 0.16666666666666666,
#  ('civilian', 'president', 'While'): 0.3333333333333333,
#  ('president', 'While', 'he'): 0.5,
#  ('While', 'he', 'announced'): 0.125,
#  ('he', 'announced', 'that'): 0.2,
#  ('announced', 'that', 'he'): 0.20454545454545456,
#  ('that', 'he', 'would'): 0.07947019867549669,
#  ('he', 'would', 'leave'): 0.011111111111111112,
#  ('would', 'leave', 'his'): 0.08333333333333333,
#  ('leave', 'his', 'military'): 0.5,
#  ('his', 'military', 'position'): 0.1,
#  ('military', 'position', 'if'): 0.3333333333333333,
#  ('position', 'if', 'he'): 1.0,
#  ('if', 'he', 'was'): 0.0641025641025641,
#  ('he', 'was', 'elected'): 0.017241379310344827,
#  ('was', 'elected', 'president'): 0.125,
#  ('elected', 'president', 'his'): 0.038461538461538464,
#  ('president', 'his', 'track'): 0.3333333333333333,
#  ('his', 'track', 'record'): 1.0,
#  ('track', 'record', 'of'): 0.35714285714285715,
#  ('record', 'of', 'reneging'): 0.024390243902439025,
#  ('of', 'reneging', 'on'): 1.0,
#  ('reneging', 'on', 'his'): 0.3333333333333333,
#  ('on', 'his', 'promises'): 0.043478260869565216,
#  ('his', 'promises', 'haunted'): 0.14285714285714285,
#  ('promises', 'haunted', 'the'): 1.0,
#  ('haunted', 'the', 'judiciary'): 0.5,
#  ('the', 'judiciary', 'The'): 0.030303030303030304,
#  ('judiciary', 'The', 'proceedings'): 0.3333333333333333,
#  ('The', 'proceedings', 'of'): 0.3333333333333333,
#  ('proceedings', 'of', 'the'): 0.8,
#  ('of', 'the', 'court'): 0.00020695364238410596,
#  ('the', 'court', 'over'): 0.029411764705882353,
#  ('court', 'over', 'the'): 0.5,
#  ('over', 'the', 'last'): 0.09030837004405286,
#  ('the', 'last', 'few'): 0.0766488413547237,
#  ('last', 'few', 'weeks'): 0.13333333333333333,
#  ('few', 'weeks', 'made'): 0.02857142857142857,
#  ('weeks', 'made', 'Musharraf'): 1.0,
#  ('made', 'Musharraf', 'jittery'): 1.0,
#  ('Musharraf', 'jittery', 'The'): 1.0,
#  ('jittery', 'The', 'decision'): 1.0,
#  ('The', 'decision', 'of'): 0.058823529411764705,
#  ('decision', 'of', 'the'): 0.3333333333333333,
#  ('of', 'the', '11member'): 6.898454746136865e-05,
#  ('the', '11member', 'bench'): 1.0,
#  ('11member', 'bench', 'might'): 1.0,
#  ('bench', 'might', 'easily'): 1.0,
#  ('might', 'easily', 'have'): 0.3333333333333333,
#  ('easily', 'have', 'gone'): 0.25,
#  ('have', 'gone', 'against'): 0.023809523809523808,
#  ('gone', 'against', 'him'): 1.0,
#  ('against', 'him', 'Legally'): 0.03571428571428571,
#  ('him', 'Legally', 'cornered'): 1.0,
#  ('Legally', 'cornered', 'Musharraf'): 1.0,
#  ('cornered', 'Musharraf', 'has'): 1.0,
#  ('Musharraf', 'has', 'now'): 0.14285714285714285,
#  ('has', 'now', 'decided'): 0.009009009009009009,
#  ('now', 'decided', 'to'): 1.0,
#  ('decided', 'to', 'abandon'): 0.010526315789473684,
#  ('to', 'abandon', 'constitutionality'): 0.015625,
#  ('abandon', 'constitutionality', 'removing'): 1.0,
#  ('constitutionality', 'removing', 'the'): 1.0,
#  ('removing', 'the', 'leading'): 0.09090909090909091,
#  ('the', 'leading', 'judges'): 0.025,
#  ('leading', 'judges', 'of'): 1.0,
#  ('judges', 'of', 'the'): 1.0,
#  ('Supreme', 'Court', 'and'): 0.10909090909090909,
#  ('Court', 'and', 'provincial'): 0.1111111111111111,
#  ('and', 'provincial', 'high'): 0.3333333333333333,
#  ('provincial', 'high', 'courts'): 1.0,
#  ('high', 'courts', 'and'): 1.0,
#  ('courts', 'and', 'putting'): 0.05263157894736842,
#  ('and', 'putting', 'curbs'): 0.09090909090909091,
#  ('putting', 'curbs', 'on'): 1.0,
#  ('curbs', 'on', 'the'): 0.5,
#  ('on', 'the', 'media'): 0.0003273322422258593,
#  ('the', 'media', 'Lawyers'): 0.008620689655172414,
#  ('media', 'Lawyers', 'human'): 1.0,
#  ('Lawyers', 'human', 'rights'): 1.0,
#  ('human', 'rights', 'activists'): 0.026871401151631478,
#  ('rights', 'activists', 'and'): 0.2222222222222222,
#  ('activists', 'and', 'political'): 0.09090909090909091,
#  ('and', 'political', 'leaders'): 0.019021739130434784,
#  ('political', 'leaders', 'have'): 0.018518518518518517,
#  ('leaders', 'have', 'since'): 0.04838709677419355,
#  ('have', 'since', 'been'): 0.23529411764705882,
#  ('since', 'been', 'arrested'): 0.1111111111111111,
#  ('been', 'arrested', 'There'): 0.1111111111111111,
#  ('arrested', 'There', 'is'): 1.0,
#  ('There', 'is', 'widespread'): 0.007312614259597806,
#  ('is', 'widespread', 'public'): 0.058823529411764705,
#  ('widespread', 'public', 'resentment'): 0.25,
#  ('public', 'resentment', 'in'): 0.5,
#  ('resentment', 'in', 'response'): 0.25,
#  ('in', 'response', 'to'): 0.9230769230769231,
#  ('response', 'to', 'these'): 0.019138755980861243,
#  ('to', 'these', 'moves'): 0.00980392156862745,
#  ('these', 'moves', 'Rather'): 1.0,
#  ('moves', 'Rather', 'than'): 1.0,
#  ('Rather', 'than', 'taking'): 0.012048192771084338,
#  ('than', 'taking', 'responsibility'): 0.3333333333333333,
#  ('taking', 'responsibility', 'for'): 1.0,
#  ('responsibility', 'for', 'the'): 0.2803030303030303,
#  ('for', 'the', 'deteriorating'): 0.00032362459546925567,
#  ('the', 'deteriorating', 'security'): 0.1111111111111111,
#  ('deteriorating', 'security', 'situation'): 1.0,
#  ('security', 'situation', 'as'): 0.1111111111111111,
#  ('situation', 'as', 'evidenced'): 0.14285714285714285,
#  ('as', 'evidenced', 'by'): 0.875,
#  ('evidenced', 'by', 'regular'): 0.1111111111111111,
#  ('by', 'regular', 'suicide'): 1.0,
#  ('regular', 'suicide', 'bomb'): 1.0,
#  ('suicide', 'bomb', 'attacks'): 1.0,
#  ('bomb', 'attacks', 'and'): 1.0,
#  ('attacks', 'and', 'the'): 0.13043478260869565,
#  ('and', 'the', 'increasing'): 0.0006155108740254411,
#  ('the', 'increasing', 'Talibanization'): 0.041666666666666664,
#  ('increasing', 'Talibanization', 'of'): 1.0,
#  ('Talibanization', 'of', 'the'): 0.6666666666666666,
#  ('of', 'the', 'tribal'): 0.0001379690949227373,
#  ('tribal', 'areas', 'Musharraf'): 0.07142857142857142,
#  ('areas', 'Musharraf', 'has'): 1.0,
#  ('Musharraf', 'has', 'tried'): 0.14285714285714285,
#  ('has', 'tried', 'to'): 0.7391304347826086,
#  ('tried', 'to', 'blame'): 0.006622516556291391,
#  ('to', 'blame', 'the'): 0.14457831325301204,
#  ('blame', 'the', 'judiciary'): 0.034482758620689655,
#  ('judiciary', 'and', 'media'): 0.058823529411764705,
#  ('and', 'media', 'To'): 0.06666666666666667,
#  ('media', 'To', 'be'): 1.0,
#  ('To', 'be', 'sure'): 0.8262910798122066,
#  ('be', 'sure', 'in'): 0.0196078431372549,
#  ('sure', 'in', 'some'): 0.25,
#  ('in', 'some', 'cases'): 0.1377551020408163,
#  ('some', 'cases', 'judicial'): 0.020833333333333332,
#  ('cases', 'judicial', 'activism'): 1.0,
#  ('judicial', 'activism', 'was'): 1.0,
#  ('activism', 'was', 'obvious'): 1.0,
#  ('was', 'obvious', 'though'): 0.14285714285714285,
#  ('obvious', 'though', 'within'): 1.0,
#  ('though', 'within', 'the'): 1.0,
#  ('within', 'the', 'realm'): 0.002932551319648094,
#  ('the', 'realm', 'of'): 0.9047619047619048,
#  ('realm', 'of', 'constitutional'): 0.05,
#  ('of', 'constitutional', 'law'): 0.1111111111111111,
#  ('constitutional', 'law', 'and'): 0.5,
#  ('and', 'the', 'media'): 0.002872384078785392,
#  ('the', 'media', 'also'): 0.017241379310344827,
#  ('media', 'also', 'made'): 0.25,
#  ('also', 'made', 'mistakes'): 0.058823529411764705,
#  ('made', 'mistakes', 'but'): 0.5,
#  ('mistakes', 'but', 'by'): 0.2,
#  ('but', 'by', 'no'): 0.07575757575757576,
#  ('by', 'no', 'stretch'): 0.034482758620689655,
#  ('no', 'stretch', 'of'): 1.0,
#  ('stretch', 'of', 'the'): 0.3333333333333333,
#  ('of', 'the', 'imagination'): 0.0001379690949227373,
#  ('the', 'imagination', 'can'): 0.125,
#  ('imagination', 'can', 'these'): 1.0,
#  ('can', 'these', 'be'): 1.0,
#  ('these', 'be', 'linked'): 1.0,
#  ('be', 'linked', 'to'): 1.0,
#  ('linked', 'to', 'religious'): 0.013888888888888888,
#  ('to', 'religious', 'extremism'): 0.09090909090909091,
#  ('religious', 'extremism', 'or'): 0.07692307692307693,
#  ('extremism', 'or', 'support'): 1.0,
#  ('or', 'support', 'for'): 0.125,
#  ('support', 'for', 'militancy'): 0.0034129692832764505,
#  ('for', 'militancy', 'It'): 1.0,
#  ('militancy', 'It', 'is'): 1.0,
#  ('It', 'is', 'unlikely'): 0.008921330089213302,
#  ('is', 'unlikely', 'that'): 0.1793103448275862,
#  ('unlikely', 'that', 'Musharrafs'): 0.025,
#  ('that', 'Musharrafs', 'latest'): 1.0,
#  ('Musharrafs', 'latest', 'gambit'): 1.0,
#  ('latest', 'gambit', 'will'): 1.0,
#  ('gambit', 'will', 'succeed'): 1.0,
#  ('will', 'succeed', 'as'): 0.0625,
#  ('succeed', 'as', 'his'): 0.2,
#  ('as', 'his', 'popular'): 0.018867924528301886,
#  ('his', 'popular', 'support'): 0.4,
#  ('popular', 'support', 'is'): 0.09090909090909091,
#  ('support', 'is', 'at'): 0.05555555555555555,
#  ('is', 'at', 'its'): 0.049689440993788817,
#  ('at', 'its', 'lowest'): 0.05747126436781609,
#  ('its', 'lowest', 'ebb'): 0.125,
#  ('lowest', 'ebb', 'Pakistans'): 1.0,
#  ('ebb', 'Pakistans', 'armed'): 1.0,
#  ('Pakistans', 'armed', 'forces'): 1.0,
#  ('armed', 'forces', 'repeated'): 0.017543859649122806,
#  ('forces', 'repeated', 'targets'): 1.0,
#  ('repeated', 'targets', 'of'): 1.0,
#  ('targets', 'of', 'suicide'): 0.08333333333333333,
#  ('of', 'suicide', 'bombers'): 0.42105263157894735,
#  ('suicide', 'bombers', 'have'): 0.03571428571428571,
#  ('bombers', 'have', 'become'): 0.5,
#  ('have', 'become', 'demoralized'): 0.006622516556291391,
#  ('become', 'demoralized', 'It'): 1.0,
#  ('demoralized', 'It', 'is'): 1.0,
#  ('It', 'is', 'difficult'): 0.024330900243309004,
#  ('is', 'difficult', 'to'): 0.7241379310344828,
#  ('difficult', 'to', 'imagine'): 0.030927835051546393,
#  ('to', 'imagine', 'them'): 0.031746031746031744,
#  ('imagine', 'them', 'standing'): 0.5,
#  ('them', 'standing', 'with'): 1.0,
#  ('standing', 'with', 'Musharraf'): 0.16666666666666666,
#  ('with', 'Musharraf', 'should'): 0.1,
#  ('Musharraf', 'should', 'civil'): 1.0,
#  ('should', 'civil', 'conflict'): 1.0,
#  ('civil', 'conflict', 'erupt'): 0.3333333333333333,
#  ('conflict', 'erupt', 'Nor'): 1.0,
#  ('erupt', 'Nor', 'can'): 1.0,
#  ('Nor', 'can', 'a'): 0.058823529411764705,
#  ('can', 'a', 'weak'): 0.1111111111111111,
#  ('a', 'weak', 'embattled'): 0.02040816326530612,
#  ('weak', 'embattled', 'and'): 1.0,
#  ('embattled', 'and', 'disoriented'): 0.5,
#  ('and', 'disoriented', 'Musharraf'): 0.3333333333333333,
#  ('disoriented', 'Musharraf', 'be'): 1.0,
#  ('Musharraf', 'be', 'expected'): 1.0,
#  ('be', 'expected', 'to'): 0.6333333333333333,
#  ('expected', 'to', 'fight'): 0.005714285714285714,
#  ('to', 'fight', 'Islamic'): 0.014084507042253521,
#  ('fight', 'Islamic', 'militancy'): 0.3333333333333333,
#  ('Islamic', 'militancy', 'effectively'): 0.3333333333333333,
#  ('militancy', 'effectively', 'or'): 1.0,
#  ('effectively', 'or', 'bring'): 1.0,
#  ('or', 'bring', 'political'): 0.3333333333333333,
#  ('bring', 'political', 'stability'): 0.5,
#  ('political', 'stability', 'to'): 0.02702702702702703,
#  ('stability', 'to', 'Pakistan'): 0.0625,
#  ('to', 'Pakistan', 'Opposition'): 0.05263157894736842,
#  ('Pakistan', 'Opposition', 'political'): 1.0,
#  ('Opposition', 'political', 'parties'): 1.0,
#  ('political', 'parties', 'are'): 0.047619047619047616,
#  ('parties', 'are', 'drawing'): 0.029411764705882353,
#  ('are', 'drawing', 'closer'): 0.25,
#  ('drawing', 'closer', 'together'): 0.5,
#  ('closer', 'together', 'and'): 0.125,
#  ('together', 'and', 'former'): 0.045454545454545456,
#  ('and', 'former', 'Prime'): 0.13793103448275862,
#  ('former', 'Prime', 'Minister'): 1.0,
#  ('Prime', 'Minister', 'Benazir'): 0.005509641873278237,
#  ('Minister', 'Benazir', 'Bhutto'): 1.0,
#  ('Benazir', 'Bhutto', 'despite'): 0.125,
#  ('Bhutto', 'despite', 'progress'): 1.0,
#  ('despite', 'progress', 'in'): 0.5,
#  ('progress', 'in', 'her'): 0.015151515151515152,
#  ('in', 'her', 'powersharing'): 0.047619047619047616,
#  ('her', 'powersharing', 'negotiations'): 1.0,
#  ('powersharing', 'negotiations', 'with'): 1.0,
#  ('negotiations', 'with', 'Musharraf'): 0.016129032258064516,
#  ('with', 'Musharraf', 'has'): 0.1,
#  ('Musharraf', 'has', 'strongly'): 0.14285714285714285,
#  ('has', 'strongly', 'condemned'): 0.5,
#  ('strongly', 'condemned', 'his'): 0.3333333333333333,
#  ('condemned', 'his', 'actions'): 1.0,
#  ('his', 'actions', 'Human'): 0.14285714285714285,
#  ('actions', 'Human', 'rights'): 1.0,
#  ('Human', 'rights', 'bodies'): 0.058823529411764705,
#  ('rights', 'bodies', 'media'): 1.0,
#  ('bodies', 'media', 'associations'): 1.0,
#  ('media', 'associations', 'and'): 1.0,
#  ('associations', 'and', 'lawyers'): 0.2,
#  ('and', 'lawyers', 'organizations'): 0.16666666666666666,
#  ('lawyers', 'organizations', 'are'): 1.0,
#  ('organizations', 'are', 'expected'): 0.09090909090909091,
#  ('are', 'expected', 'to'): 0.9696969696969697,
#  ('expected', 'to', 'defy'): 0.005714285714285714,
#  ('to', 'defy', 'the'): 0.8333333333333334,
#  ('defy', 'the', 'emergency'): 0.125,
#  ('the', 'emergency', 'which'): 0.125,
#  ('emergency', 'which', 'will'): 1.0,
#  ('which', 'will', 'pit'): 0.009708737864077669,
#  ('will', 'pit', 'them'): 0.5,
#  ('pit', 'them', 'against'): 1.0,
#  ('them', 'against', 'the'): 0.3333333333333333,
#  ('against', 'the', 'security'): 0.002028397565922921,
#  ('the', 'security', 'forces'): 0.14473684210526316,
#  ('security', 'forces', 'Terrorists'): 0.02857142857142857,
#  ('forces', 'Terrorists', 'may'): 1.0,
#  ('Terrorists', 'may', 'also'): 1.0,
#  ('may', 'also', 'benefit'): 0.013333333333333334,
#  ('also', 'benefit', 'by'): 0.1111111111111111,
#  ('benefit', 'by', 'attacking'): 0.5,
#  ('by', 'attacking', 'a'): 0.2222222222222222,
#  ('attacking', 'a', 'preoccupied'): 0.16666666666666666,
#  ('a', 'preoccupied', 'army'): 1.0,
#  ('preoccupied', 'army', 'and'): 1.0,
#  ('army', 'and', 'political'): 0.038461538461538464,
#  ('and', 'political', 'forces'): 0.002717391304347826,
#  ('political', 'forces', 'aligned'): 0.045454545454545456,
#  ('forces', 'aligned', 'with'): 1.0,
#  ('aligned', 'with', 'Musharraf'): 0.0625,
#  ('with', 'Musharraf', 'In'): 0.1,
#  ('Musharraf', 'In', 'the'): 1.0,
#  ('In', 'the', 'event'): 0.005263157894736842,
#  ('the', 'event', 'of'): 0.5142857142857142,
#  ('event', 'of', 'sustained'): 0.047619047619047616,
#  ('of', 'sustained', 'protests'): 0.08333333333333333,
#  ('sustained', 'protests', 'and'): 1.0,
#  ('protests', 'and', 'potential'): 0.08333333333333333,
#  ('and', 'potential', 'violence'): 0.0625,
#  ('potential', 'violence', 'top'): 1.0,
#  ('violence', 'top', 'military'): 1.0,
#  ('top', 'military', 'commanders'): 1.0,
#  ('military', 'commanders', 'may'): 0.2,
#  ('commanders', 'may', 'decide'): 1.0,
#  ('may', 'decide', 'to'): 0.625,
#  ('decide', 'to', 'send'): 0.029411764705882353,
#  ('to', 'send', 'Musharraf'): 0.017857142857142856,
#  ('send', 'Musharraf', 'home'): 1.0,
#  ('Musharraf', 'home', 'a'): 1.0,
#  ('home', 'a', 'decision'): 0.25,
#  ('a', 'decision', 'that'): 0.08571428571428572,
#  ('decision', 'that', 'would'): 0.14285714285714285,
#  ('that', 'would', 'not'): 0.02666666666666667,
#  ('would', 'not', 'be'): 0.25,
#  ('not', 'be', 'unprecedented'): 0.0013513513513513514,
#  ('be', 'unprecedented', 'in'): 1.0,
#  ('unprecedented', 'in', 'Pakistans'): 0.08333333333333333,
#  ('in', 'Pakistans', 'chronically'): 0.125,
#  ('Pakistans', 'chronically', 'turbulent'): 1.0,
#  ('chronically', 'turbulent', 'history'): 1.0,
#  ('turbulent', 'history', 'The'): 1.0,
#  ('history', 'The', 'Making'): 0.05,
#  ('The', 'Making', 'of'): 1.0,
#  ('Making', 'of', 'a'): 0.5,
#  ('of', 'a', 'Murder'): 0.0004042037186742118,
#  ('a', 'Murder', 'in'): 1.0,
#  ('Murder', 'in', 'Pakistan'): 0.5,
#  ('in', 'Pakistan', 'Instead'): 0.013333333333333334,
#  ('Pakistan', 'Instead', 'Bhutto'): 1.0,
#  ('Instead', 'Bhutto', 'had'): 1.0,
#  ('Bhutto', 'had', 'to'): 0.25,
#  ('had', 'to', 'pay'): 0.017543859649122806,
#  ('to', 'pay', 'with'): 0.015625,
#  ('pay', 'with', 'her'): 0.2,
#  ('with', 'her', 'life'): 0.07692307692307693,
#  ('her', 'life', 'for'): 0.25,
#  ('life', 'for', 'courageously'): 0.05263157894736842,
#  ('for', 'courageously', 'challenging'): 1.0,
#  ('courageously', 'challenging', 'extremists'): 1.0,
#  ('challenging', 'extremists', 'of'): 1.0,
#  ('extremists', 'of', 'all'): 0.5,
#  ('of', 'all', 'stripes'): 0.014184397163120567,
#  ('all', 'stripes', 'from'): 0.3333333333333333,
#  ('stripes', 'from', 'AlQaeda'): 0.5,
#  ('from', 'AlQaeda', 'and'): 1.0,
#  ('AlQaeda', 'and', 'Taliban'): 0.5,
#  ('and', 'Taliban', 'to'): 0.3333333333333333,
#  ('Taliban', 'to', 'the'): 0.5,
#  ('to', 'the', 'countrys'): 0.004521613311629589,
#  ('the', 'countrys', 'religious'): 0.002,
#  ('countrys', 'religious', 'political'): 0.5,
#  ('religious', 'political', 'parties'): 0.5,
#  ('political', 'parties', 'and'): 0.12698412698412698,
#  ('parties', 'and', 'military'): 0.021739130434782608,
#  ('and', 'military', 'hardliners'): 0.01,
#  ('military', 'hardliners', 'As'): 1.0,
#  ('hardliners', 'As', 'heir'): 1.0,
#  ('As', 'heir', 'to'): 1.0,
#  ('heir', 'to', 'Zulfikar'): 0.5,
#  ('to', 'Zulfikar', 'Ali'): 1.0,
#  ('Zulfikar', 'Ali', 'Bhutto'): 1.0,
#  ('Ali', 'Bhutto', 'the'): 0.5,
#  ('Bhutto', 'the', 'legendary'): 1.0,
#  ('the', 'legendary', 'democratic'): 0.25,
#  ('legendary', 'democratic', 'leader'): 1.0,
#  ('democratic', 'leader', 'who'): 0.5,
#  ('leader', 'who', 'was'): 0.09523809523809523,
#  ('who', 'was', 'hanged'): 0.010101010101010102,
#  ('was', 'hanged', 'by'): 1.0,
#  ('hanged', 'by', 'General'): 1.0,
#  ('by', 'General', 'Muhammad'): 0.125,
#  ('General', 'Muhammad', 'ZiaulHaqs'): 0.5,
#  ('Muhammad', 'ZiaulHaqs', 'government'): 1.0,
#  ('ZiaulHaqs', 'government', 'in'): 1.0,
#  ('government', 'in', '1979'): 0.010309278350515464,
#  ('in', '1979', 'Benazir'): 0.043478260869565216,
#  ('1979', 'Benazir', 'emerged'): 1.0,
#  ('Benazir', 'emerged', 'as'): 1.0,
#  ('emerged', 'as', 'a'): 0.375,
#  ('as', 'a', 'symbol'): 0.0036596523330283625,
#  ('a', 'symbol', 'of'): 0.8947368421052632,
#  ('symbol', 'of', 'resistance'): 0.02702702702702703,
#  ('of', 'resistance', 'at'): 0.08333333333333333,
#  ('resistance', 'at', 'a'): 0.3333333333333333,
#  ('at', 'a', 'young'): 0.0024875621890547263,
#  ('a', 'young', 'age'): 0.030303030303030304,
#  ('young', 'age', 'but'): 0.5,
#  ('age', 'but', 'languished'): 0.5,
#  ('but', 'languished', 'in'): 1.0,
#  ('languished', 'in', 'jails'): 0.5,
#  ('in', 'jails', 'and'): 0.5,
#  ('jails', 'and', 'exile'): 0.25,
#  ('and', 'exile', 'in'): 0.3333333333333333,
#  ('exile', 'in', 'the'): 0.42857142857142855,
#  ('in', 'the', '1980s'): 0.00819366852886406,
#  ('the', '1980s', 'Z'): 0.0056179775280898875,
#  ('1980s', 'Z', 'A'): 1.0,
#  ('Z', 'A', 'Bhuttos'): 1.0,
#  ('A', 'Bhuttos', 'legacy'): 1.0,
#  ('Bhuttos', 'legacy', 'was'): 1.0,
#  ('legacy', 'was', 'empowerment'): 0.2,
#  ('was', 'empowerment', 'of'): 1.0,
#  ('empowerment', 'of', 'the'): 0.2857142857142857,
#  ('of', 'the', 'impoverished'): 6.898454746136865e-05,
#  ('the', 'impoverished', 'and'): 0.25,
#  ('impoverished', 'and', 'defense'): 0.125,
#  ('and', 'defense', 'of'): 0.1282051282051282,
#  ('defense', 'of', 'ordinary'): 0.04,
#  ('of', 'ordinary', 'peoples'): 0.029411764705882353,
#  ('ordinary', 'peoples', 'rights'): 1.0,
#  ('peoples', 'rights', 'amid'): 1.0,
#  ('rights', 'amid', 'feudalistic'): 1.0,
#  ('amid', 'feudalistic', 'politics'): 1.0,
#  ('feudalistic', 'politics', 'and'): 1.0,
#  ('politics', 'and', 'military'): 0.010869565217391304,
#  ('and', 'military', 'rule'): 0.01,
#  ('military', 'rule', 'Rather'): 0.058823529411764705,
#  ('rule', 'Rather', 'than'): 1.0,
#  ('Rather', 'than', 'bowing'): 0.012048192771084338,
#  ('than', 'bowing', 'to'): 1.0,
#  ('bowing', 'to', 'the'): 0.6,
#  ('to', 'the', 'military'): 0.0018086453246518358,
#  ('the', 'military', 'junta'): 0.03125,
#  ('military', 'junta', 'he'): 0.09090909090909091,
#  ('junta', 'he', 'embraced'): 1.0,
#  ('he', 'embraced', 'the'): 1.0,
#  ('embraced', 'the', 'gallows'): 0.07692307692307693,
#  ('the', 'gallows', 'Hours'): 0.5,
#  ('gallows', 'Hours', 'before'): 1.0,
#  ('Hours', 'before', 'his'): 1.0,
#  ('before', 'his', 'hanging'): 0.06666666666666667,
#  ('his', 'hanging', 'Benazir'): 1.0,
#  ('hanging', 'Benazir', 'was'): 1.0,
#  ('Benazir', 'was', 'allowed'): 1.0,
#  ('was', 'allowed', 'to'): 0.8,
#  ('allowed', 'to', 'see'): 0.006289308176100629,
#  ('to', 'see', 'her'): 0.006622516556291391,
#  ('see', 'her', 'father'): 0.5,
#  ('her', 'father', 'for'): 0.5,
#  ('father', 'for', 'the'): 1.0,
#  ('for', 'the', 'last'): 0.007766990291262136,
#  ('the', 'last', 'time'): 0.0071301247771836,
#  ('last', 'time', 'writing'): 0.08333333333333333,
#  ('time', 'writing', 'in'): 1.0,
#  ('writing', 'in', 'her'): 0.3333333333333333,
#  ('in', 'her', 'autobiography'): 0.047619047619047616,
#  ('her', 'autobiography', 'I'): 1.0,
#  ('autobiography', 'I', 'told'): 1.0,
#  ('I', 'told', 'him'): 0.2857142857142857,
#  ('told', 'him', 'on'): 0.16666666666666666,
#  ('him', 'on', 'my'): 0.07692307692307693,
#  ('on', 'my', 'oath'): 0.09090909090909091,
#  ('my', 'oath', 'in'): 1.0,
#  ('oath', 'in', 'his'): 1.0,
#  ('in', 'his', 'death'): 0.004032258064516129,
#  ('his', 'death', 'cell'): 0.058823529411764705,
#  ('death', 'cell', 'I'): 1.0,
#  ('cell', 'I', 'would'): 1.0,
#  ('I', 'would', 'carry'): 0.02,
#  ('would', 'carry', 'on'): 0.5,
#  ('carry', 'on', 'his'): 0.25,
#  ('on', 'his', 'work'): 0.010869565217391304,
#  ('his', 'work', 'She'): 0.06666666666666667,
#  ('work', 'She', 'largely'): 1.0,
#  ('She', 'largely', 'lived'): 1.0,
#  ('largely', 'lived', 'up'): 1.0,
#  ('lived', 'up', 'to'): 1.0,
#  ('up', 'to', 'the'): 0.22969187675070027,
#  ('to', 'the', 'promise'): 0.00018086453246518358,
#  ('the', 'promise', 'Her'): 0.025,
#  ('promise', 'Her', 'first'): 1.0,
#  ('Her', 'first', 'stint'): 1.0,
#  ('first', 'stint', 'as'): 1.0,
#  ('stint', 'as', 'prime'): 0.5,
#  ('as', 'prime', 'minister'): 0.9444444444444444,
#  ('prime', 'minister', '198890'): 0.005681818181818182,
#  ('minister', '198890', 'was'): 1.0,
#  ('198890', 'was', 'brief'): 1.0,
#  ('was', 'brief', 'and'): 0.5,
#  ('brief', 'and', 'disorganized'): 1.0,
#  ('and', 'disorganized', 'Lt'): 1.0,
#  ('disorganized', 'Lt', 'Gen'): 1.0,
#  ('Lt', 'Gen', 'Hamid'): 0.5,
#  ('Gen', 'Hamid', 'Gul'): 1.0,
#  ('Hamid', 'Gul', 'the'): 1.0,
#  ('Gul', 'the', 'former'): 1.0,
#  ('the', 'former', 'InterServices'): 0.004694835680751174,
#  ('former', 'InterServices', 'Intelligence'): 1.0,
#  ('InterServices', 'Intelligence', 'ISI'): 0.7142857142857143,
#  ('Intelligence', 'ISI', 'chief'): 0.2,
#  ('ISI', 'chief', 'confirmed'): 1.0,
#  ('chief', 'confirmed', 'that'): 1.0,
#  ('confirmed', 'that', 'he'): 0.08333333333333333,
#  ('that', 'he', 'sponsored'): 0.002207505518763797,
#  ('he', 'sponsored', 'an'): 0.5,
#  ('sponsored', 'an', 'alliance'): 1.0,
#  ('an', 'alliance', 'of'): 0.17647058823529413,
#  ('alliance', 'of', 'rightwing'): 0.05263157894736842,
#  ('of', 'rightwing', 'political'): 0.1111111111111111,
#  ('rightwing', 'political', 'parties'): 1.0,
#  ('political', 'parties', 'to'): 0.07142857142857142,
#  ('parties', 'to', 'stop'): 0.023255813953488372,
#  ('to', 'stop', 'her'): 0.006993006993006993,
#  ('stop', 'her', 'from'): 1.0,
#  ('her', 'from', 'getting'): 0.16666666666666666,
#  ('from', 'getting', 'a'): 0.1111111111111111,
#  ('getting', 'a', 'parliamentary'): 0.07142857142857142,
#  ('a', 'parliamentary', 'majority'): 0.4090909090909091,
#  ('parliamentary', 'majority', 'Information'): 0.043478260869565216,
#  ('majority', 'Information', 'about'): 1.0,
#  ('Information', 'about', 'Pakistans'): 1.0,
#  ('about', 'Pakistans', 'nuclear'): 1.0,
#  ('Pakistans', 'nuclear', 'program'): 0.16666666666666666,
#  ('nuclear', 'program', 'and'): 0.18571428571428572,
#  ('program', 'and', 'ISI'): 0.029411764705882353,
#  ('and', 'ISI', 'operations'): 1.0,
#  ('ISI', 'operations', 'in'): 1.0,
#  ('operations', 'in', 'Afghanistan'): 0.08,
#  ('in', 'Afghanistan', 'were'): 0.011299435028248588,
#  ('Afghanistan', 'were', 'out'): 0.3333333333333333,
#  ('were', 'out', 'of'): 1.0,
#  ('out', 'of', 'her'): 0.004087193460490463,
#  ('of', 'her', 'domain'): 0.019230769230769232,
#  ('her', 'domain', 'Her'): 1.0,
#  ('domain', 'Her', 'second'): 1.0,
#  ('Her', 'second', 'term'): 1.0,
#  ('second', 'term', 'in'): 0.17857142857142858,
#  ('term', 'in', 'office'): 0.5,
#  ('in', 'office', '199396'): 0.014492753623188406,
#  ('office', '199396', 'was'): 1.0,
#  ('199396', 'was', 'longer'): 1.0,
#  ('was', 'longer', 'and'): 1.0,
#  ('longer', 'and', 'better'): 0.2,
#  ('and', 'better', 'but'): 0.018518518518518517,
#  ('better', 'but', 'her'): 0.2,
#  ('but', 'her', 'government'): 0.5,
#  ('her', 'government', 'again'): 0.125,
#  ('government', 'again', 'fell'): 1.0,
#  ('again', 'fell', 'early'): 0.5,
#  ('fell', 'early', 'owing'): 1.0,
#  ('early', 'owing', 'to'): 1.0,
#  ('owing', 'to', 'charges'): 0.013513513513513514,
#  ('to', 'charges', 'of'): 0.7142857142857143,
#  ('charges', 'of', 'mismanagement'): 0.030303030303030304,
#  ('of', 'mismanagement', 'and'): 0.6666666666666666,
#  ('mismanagement', 'and', 'corruption'): 0.2,
#  ('and', 'corruption', 'In'): 0.02857142857142857,
#  ('corruption', 'In', 'reality'): 0.3333333333333333,
#  ('In', 'reality', 'machinations'): 0.03125,
#  ('reality', 'machinations', 'by'): 1.0,
#  ('machinations', 'by', 'the'): 0.6666666666666666,
#  ('by', 'the', 'intelligence'): 0.00039556962025316455,
#  ('the', 'intelligence', 'agencies'): 0.15384615384615385,
#  ('intelligence', 'agencies', 'also'): 0.1,
#  ('agencies', 'also', 'played'): 1.0,
#  ('also', 'played', 'a'): 0.6666666666666666,
#  ('played', 'a', 'part'): 0.08,
#  ('a', 'part', 'The'): 0.015873015873015872,
#  ('part', 'The', 'military'): 0.25,
#  ('The', 'military', 'had'): 0.13333333333333333,
#  ('military', 'had', 'developed'): 0.3333333333333333,
#  ('had', 'developed', 'an'): 0.16666666666666666,
#  ('developed', 'an', 'entrenched'): 0.25,
#  ('an', 'entrenched', 'distrust'): 0.16666666666666666,
#  ('entrenched', 'distrust', 'of'): 1.0,
#  ('distrust', 'of', 'her'): 0.07142857142857142,
#  ('of', 'her', 'given'): 0.019230769230769232,
#  ('her', 'given', 'her'): 1.0,
#  ('given', 'her', 'position'): 0.5,
#  ('her', 'position', 'as'): 1.0,
#  ('position', 'as', 'a'): 0.3181818181818182,
#  ('as', 'a', 'popularly'): 0.0004574565416285453,
#  ('a', 'popularly', 'supported'): 0.2,
#  ('popularly', 'supported', 'proWestern'): 1.0,
#  ('supported', 'proWestern', 'leader'): 1.0,
#  ('proWestern', 'leader', 'who'): 1.0,
#  ('leader', 'who', 'wanted'): 0.047619047619047616,
#  ('who', 'wanted', 'peace'): 0.09090909090909091,
#  ('wanted', 'peace', 'with'): 1.0,
#  ('peace', 'with', 'India'): 0.017241379310344827,
#  ('with', 'India', 'After'): 0.03571428571428571,
#  ('India', 'After', 'almost'): 1.0,
#  ('After', 'almost', 'a'): 1.0,
#  ('almost', 'a', 'decade'): 0.3333333333333333,
#  ('a', 'decade', 'in'): 0.016129032258064516,
#  ...}

# %%
# plus one smoothing
add_one_probs={}
for trigram_value, trigram_count in trigram_freq.items():
    add_one_probs[trigram_value] = (trigram_count + 1) / (bigram_freq[trigram_value[:-1]] + vocabulary)

# %%
import numpy as np
# prob of sentence
def sentence_prob(sentence):
    sentence_trigrams = get_ngrams(sentence, 3)
    prob_list = []
    for i in sentence_trigrams:
        prob_list.append(add_one_probs[i])
    return np.prod(prob_list)

sentence_prob('this is a test')
# Out:
# 5.515789681589914e-11

# %%
# calculate perplexity
def get_perp(sentence):
    sentence_trigrams = get_ngrams(sentence, 3)
    log_list = []
    for i in sentence_trigrams:
        try:
            log_list.append(np.log2(add_one_probs[i]))
        except KeyError:
            log_list.append(0)
            continue
    return (sum(log_list))/len(sentence_trigrams)

# %%
from nltk.tokenize import sent_tokenize

test = preprocess("test-2.2.txt")

tokenized_test = sent_tokenize(test)

for i in tokenized_test:
    print(get_perp(i))
# Out:
# -4.559848682138508
# -5.978471917084863
# -7.3762999337096
# -4.937548132239096
# 0.0
# -0.9822961708788477
# -5.499176778368703
# -6.097299204716596
# -4.576311455084519
# -2.9964734515740092
# 0.0
# -2.5259044394027512
# -2.1575882138299773
# -5.765669144827017
# -2.9291074440008846
# -9.093461585706747
# -7.002931376744497
# -3.709058527178596
# -5.199403235134223
# -9.662193234671136
# -4.007537635800398
# 0.0
# -3.884122296263707
# -5.362501404848392
# -13.74246984446396
